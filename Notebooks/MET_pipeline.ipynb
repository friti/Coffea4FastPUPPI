# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import matplotlib as mpl
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import mplhep as hep
hep.style.use("CMS")

# %%
## NOTE: In this file PUPPI == PF candidates
## -----------------------------------------

#file_path = "/eos/cms/store/cmst3/group/l1tr/elfontan/l1tPFplusPuppi/fp_ntuples_NNVtx_151X/TT_PU200/FP/151Xv0/perfNano_16283968_110.root"
#file_path = "/eos/cms/store/cmst3/group/l1tr/elfontan/l1tPFplusPuppi/fp_ntuples_NNVtx_151X/TT_PU200/perfNano_PU200.root"
file_path = "/eos/cms/store/cmst3/group/l1tr/elfontan/l1tPFplusPuppi/fp_ntuples_151X_targetStudies/perfNano_PU200.root"

file = uproot.open(file_path)
events = file["Events"]
print("Branches in 'Events':")
print(events.keys())
print(len(events))

n_events_to_process = 10000
# Out:
# Branches in 'Events':
# ['run', 'luminosityBlock', 'event', 'bunchCrossing', 'orbitNumber', 'nDecEmCaloBarrel', 'DecEmCaloBarrel_hwEta', 'DecEmCaloBarrel_hwPhi', 'DecEmCaloBarrel_hwQual', 'DecEmCaloBarrel_eta', 'DecEmCaloBarrel_phi', 'DecEmCaloBarrel_pt', 'nDecEmCaloHGCalNoTK', 'DecEmCaloHGCalNoTK_hwEta', 'DecEmCaloHGCalNoTK_hwPhi', 'DecEmCaloHGCalNoTK_hwQual', 'DecEmCaloHGCalNoTK_eta', 'DecEmCaloHGCalNoTK_phi', 'DecEmCaloHGCalNoTK_pt', 'nDecEmCaloHGCal', 'DecEmCaloHGCal_hwEta', 'DecEmCaloHGCal_hwPhi', 'DecEmCaloHGCal_hwQual', 'DecEmCaloHGCal_eta', 'DecEmCaloHGCal_phi', 'DecEmCaloHGCal_pt', 'nDecHadCaloBarrel', 'DecHadCaloBarrel_hwEta', 'DecHadCaloBarrel_hwPhi', 'DecHadCaloBarrel_hwQual', 'DecHadCaloBarrel_eta', 'DecHadCaloBarrel_phi', 'DecHadCaloBarrel_pt', 'nDecHadCaloHGCalNoTK', 'DecHadCaloHGCalNoTK_hwEta', 'DecHadCaloHGCalNoTK_hwPhi', 'DecHadCaloHGCalNoTK_hwQual', 'DecHadCaloHGCalNoTK_eta', 'DecHadCaloHGCalNoTK_phi', 'DecHadCaloHGCalNoTK_pt', 'nDecHadCaloHGCal', 'DecHadCaloHGCal_hwEta', 'DecHadCaloHGCal_hwPhi', 'DecHadCaloHGCal_hwQual', 'DecHadCaloHGCal_eta', 'DecHadCaloHGCal_phi', 'DecHadCaloHGCal_pt', 'nGenPi', 'GenPi_charge', 'GenPi_prompt', 'GenPi_eta', 'GenPi_phi', 'GenPi_pt', 'GenPi_vz', 'nGenCands', 'GenCands_hasMatchedGenNeutral', 'GenCands_isGenMatched', 'GenCands_nRecoInCone0p2', 'GenCands_nRecoChInCone0p2', 'GenCands_nRecoNeInCone0p2', 'GenCands_nRecoPhoInCone0p2', 'GenCands_nRecoNHadInCone0p2', 'GenCands_nRecoChHadInCone0p2', 'GenCands_nGenInCone0p2', 'GenCands_nGenChInCone0p2', 'GenCands_nGenNeInCone0p2', 'GenCands_nGenPhoInCone0p2', 'GenCands_nGenNHadInCone0p2', 'GenCands_nGenChHadInCone0p2', 'GenCands_pt', 'GenCands_eta', 'GenCands_phi', 'GenCands_mass', 'GenCands_charge', 'GenCands_pdgId', 'GenCands_prompt', 'GenCands_status', 'GenCands_vz', 'GenCands_genPtSum0p2', 'GenCands_genNeutralPtSum0p2', 'GenCands_genChargedPtSum0p2', 'GenCands_recoPtSum0p2', 'GenCands_recoNeutralPtSum0p2', 'GenCands_recoChargedPtSum0p2', 'GenCands_recoDen_seedPlusCh0p2', 'GenCands_recoDen_seedPlusNe0p2', 'GenCands_recoDen_seedPlusAll0p2', 'GenCands_genChPlusMatchedNe0p2', 'GenCands_ratioPU_ch0p2', 'GenCands_ratioPU_ne0p2', 'GenCands_ratioPU_all0p2', 'GenCands_matchedGenNeutralPt', 'GenCands_caloeta', 'GenCands_calophi', 'nL1PFCands', 'L1PFCands_hasMatchedGenNeutral', 'L1PFCands_isGenMatched', 'L1PFCands_nRecoInCone0p2', 'L1PFCands_nRecoChInCone0p2', 'L1PFCands_nRecoNeInCone0p2', 'L1PFCands_nRecoPhoInCone0p2', 'L1PFCands_nRecoNHadInCone0p2', 'L1PFCands_nRecoChHadInCone0p2', 'L1PFCands_nGenInCone0p2', 'L1PFCands_nGenChInCone0p2', 'L1PFCands_nGenNeInCone0p2', 'L1PFCands_nGenPhoInCone0p2', 'L1PFCands_nGenNHadInCone0p2', 'L1PFCands_nGenChHadInCone0p2', 'L1PFCands_pt', 'L1PFCands_eta', 'L1PFCands_phi', 'L1PFCands_mass', 'L1PFCands_caloEta', 'L1PFCands_caloPhi', 'L1PFCands_charge', 'L1PFCands_dxy', 'L1PFCands_hgcIdEm', 'L1PFCands_hgcIdPi', 'L1PFCands_hgcIdPu', 'L1PFCands_hwTkQuality', 'L1PFCands_nnVtxScore', 'L1PFCands_pdgId', 'L1PFCands_puppiWeight', 'L1PFCands_z0', 'L1PFCands_genPtSum0p2', 'L1PFCands_genNeutralPtSum0p2', 'L1PFCands_genChargedPtSum0p2', 'L1PFCands_recoPtSum0p2', 'L1PFCands_recoNeutralPtSum0p2', 'L1PFCands_recoChargedPtSum0p2', 'L1PFCands_recoDen_seedPlusCh0p2', 'L1PFCands_recoDen_seedPlusNe0p2', 'L1PFCands_recoDen_seedPlusAll0p2', 'L1PFCands_genChPlusMatchedNe0p2', 'L1PFCands_ratioPU_ch0p2', 'L1PFCands_ratioPU_ne0p2', 'L1PFCands_ratioPU_all0p2', 'L1PFCands_matchedGenNeutralPt', 'L1PFCands_caloeta', 'L1PFCands_calophi', 'nL1PuppiCands', 'L1PuppiCands_hasMatchedGenNeutral', 'L1PuppiCands_isGenMatched', 'L1PuppiCands_nRecoInCone0p2', 'L1PuppiCands_nRecoChInCone0p2', 'L1PuppiCands_nRecoNeInCone0p2', 'L1PuppiCands_nRecoPhoInCone0p2', 'L1PuppiCands_nRecoNHadInCone0p2', 'L1PuppiCands_nRecoChHadInCone0p2', 'L1PuppiCands_nGenInCone0p2', 'L1PuppiCands_nGenChInCone0p2', 'L1PuppiCands_nGenNeInCone0p2', 'L1PuppiCands_nGenPhoInCone0p2', 'L1PuppiCands_nGenNHadInCone0p2', 'L1PuppiCands_nGenChHadInCone0p2', 'L1PuppiCands_pt', 'L1PuppiCands_eta', 'L1PuppiCands_p ...
# 440

# %% [markdown]
# ## Check for basic MET computation

# %%
arrays = events.arrays(
    entry_start=0, 
    entry_stop=n_events_to_process, 
    library="np"
)
puppi_pt = arrays["L1PuppiCands_pt"]
puppi_phi = arrays["L1PuppiCands_phi"]
puppi_eta = arrays["L1PuppiCands_eta"]
puppi_mass = arrays["L1PuppiCands_mass"]

# %%
puppi_met_x = [-np.sum(pt * np.cos(phi)) for pt, phi in zip(puppi_pt, puppi_phi)]
puppi_met_y = [-np.sum(pt * np.sin(phi)) for pt, phi in zip(puppi_pt, puppi_phi)]
puppi_met = [np.sqrt(mx**2 + my**2) for mx, my in zip(puppi_met_x, puppi_met_y)]

# %%
puppi_met_stored = arrays["L1PuppiMet_pt"]
puppi_met_diff = np.array(puppi_met) - np.array(puppi_met_stored)
print("First 10 calculated vs stored MET:")
for i in range(10):
    print(puppi_met_diff[i])
    if puppi_met_diff[i] > 0 or puppi_met_diff[i] < 0:
        print(f"Event {i}: calc={puppi_met[i]:.2f}, stored={puppi_met_stored[i]:.2f}, diff={puppi_met_diff[i]:.2f}")
# Out:
# First 10 calculated vs stored MET:
# -1.4591270648622867e-05
# Event 0: calc=21.30, stored=21.30, diff=-0.00
# -7.649041286583724e-06
# Event 1: calc=37.65, stored=37.65, diff=-0.00
# 1.6173920869277936e-06
# Event 2: calc=211.51, stored=211.51, diff=0.00
# -1.448574357709731e-05
# Event 3: calc=223.31, stored=223.31, diff=-0.00
# 1.9577219084965236e-05
# Event 4: calc=62.80, stored=62.80, diff=0.00
# 2.4152003874178263e-05
# Event 5: calc=100.62, stored=100.62, diff=0.00
# 5.401720547304478e-06
# Event 6: calc=7.45, stored=7.45, diff=0.00
# 2.173514872083615e-05
# Event 7: calc=27.98, stored=27.98, diff=0.00
# -1.4587412067612604e-05
# Event 8: calc=167.22, stored=167.22, diff=-0.00
# -1.7711426515631956e-05
# Event 9: calc=28.66, stored=28.66, diff=-0.00

# %%
# Plot MET comparisons
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(puppi_met_stored, puppi_met, s=2, label='PUPPI')
plt.plot([min(puppi_met_stored), max(puppi_met_stored)], [min(puppi_met_stored), max(puppi_met_stored)], 'r--', label='y=x')
plt.xlabel('Stored PUPPI MET')
plt.ylabel('Calculated PUPPI MET')
plt.legend()
plt.title('PUPPI MET: Stored vs Calculated')

plt.subplot(1,2,2)
plt.hist(puppi_met_diff, bins=50, alpha=0.7, label='PUPPI diff')
plt.xlabel('Calculated - Stored MET')
plt.ylabel('Events')
plt.title('PUPPI MET Difference')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Check for PUPPI and PF multiplicity

# %%
n_pf = arrays["nL1PFCands"]
n_puppi = arrays["nL1PuppiCands"]

# Plot multiplicities
plt.figure(figsize=(7,7))
bins = np.linspace(0, 700, 50)

plt.hist(n_pf, bins=bins, alpha=0.7, label='PF')
plt.hist(n_puppi, bins=bins, alpha=0.7, label='PUPPI')
plt.xlabel('Multiplicity')
plt.ylabel('Events')
plt.legend()

plt.tight_layout()
plt.show()

plt.figure(figsize=(7,7))

# %% [markdown]
# ## Make original PUPPI collection

# %%
# Load branches
pt = arrays["L1PuppiCands_pt"]
phi = arrays["L1PuppiCands_phi"]
eta = arrays["L1PuppiCands_eta"]
mass = arrays["L1PuppiCands_mass"]
weight = arrays["L1PuppiCands_puppiWeight"]
charge = arrays["L1PuppiCands_charge"]
nnVtxScore = arrays["L1PuppiCands_nnVtxScore"]
pdgid = arrays["L1PuppiCands_pdgId"]

# %%
# ---------------------------- #
# --- Build Awkward arrays --- #
# ---------------------------- #
# If pt/weight/charge are numpy arrays with dtype=object, convert to python lists first.

def to_ak(x):
    if isinstance(x, np.ndarray) and x.dtype == object:
        x = x.tolist()
    return ak.Array(x)

akpt     = to_ak(pt)
akweight = to_ak(weight)
akcharge = to_ak(charge)

# --- SELECT ONLY NEUTRAL CANDIDATES ---
neutral_mask = (akcharge == 0)

pt_neutral     = akpt[neutral_mask]
weight_neutral = akweight[neutral_mask]

# Corrected pT (current PUPPI weight)
pt_corr_neutral = pt_neutral * weight_neutral

# --- SAFE FLATTENING + conversion to numpy ---
# First drop missing values (None) at the awkward level, then convert
flat_pt      = ak.to_numpy(ak.flatten(ak.drop_none(pt_neutral), axis=None))
flat_pt_corr = ak.to_numpy(ak.flatten(ak.drop_none(pt_corr_neutral), axis=None))

# Remove NaN/inf (only works once they're numeric numpy arrays)
flat_pt      = flat_pt[np.isfinite(flat_pt)]
flat_pt_corr = flat_pt_corr[np.isfinite(flat_pt_corr)]

# -------------------------------
#        Plot
# -------------------------------
plt.figure(figsize=(10, 6))
bins = np.linspace(0, 30, 60)

plt.hist(flat_pt, bins=bins, histtype="step", linewidth=2, density=True,
         label="Original reco pT")
plt.hist(flat_pt_corr, bins=bins, histtype="step", linewidth=2, density=True,
         label="Corrected reco pT (current PUPPI)")

plt.xlabel("pT [GeV]")
plt.ylabel("Candidates")  # (density=True means this is a PDF, but label is fine if you prefer)
plt.title("Neutral candidates pT distribution")
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 26
#      22 pt_corr_neutral = pt_neutral * weight_neutral
#      24 # --- SAFE FLATTENING + conversion to numpy ---
#      25 # First drop missing values (None) at the awkward level, then convert
# ---> 26 flat_pt      = ak.to_numpy(ak.flatten(ak.drop_none(pt_neutral), axis=None))
#      27 flat_pt_corr = ak.to_numpy(ak.flatten(ak.drop_none(pt_corr_neutral), axis=None))
#      29 # Remove NaN/inf (only works once they're numeric numpy arrays)
#
# AttributeError: module 'awkward' has no attribute 'drop_none'

# %%
selected_counts = []
selected_pts = []     # list of lists
selected_etas = []
selected_phis = []
selected_masses = []
selected_effective_pts = []  # pt after weighting (for MET)

for iev in range(len(pt)):

    sel_pt = []
    sel_eta = []
    sel_phi = []
    sel_mass = []
    sel_effpt = []   # pt used in MET (pt*weight or pt)

    for pt_i, weight_i, charge_i, nnVtxScore_i, eta_i, phi_i, mass_i, pdgid_i in zip(
            pt[iev], weight[iev], charge[iev], nnVtxScore[iev],
            eta[iev], phi[iev], mass[iev], pdgid[iev]):

        abs_eta = abs(eta_i)

        ###############
        # Barrel
        ###############
        if abs_eta < 1.5:

            if charge_i == 0:
                if np.round((pt_i * weight_i) / 0.25) * 0.25 >= 1.0:
                    eff_pt = pt_i * weight_i
                    eff_pt = np.round(eff_pt / 0.25) * 0.25
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)
            if charge_i !=0:
                if nnVtxScore_i > 0.1:
                    eff_pt = pt_i
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)
        ###############
        # HGCAL with TK
        ###############
        if 1.5 < abs_eta < 2.5:

            if charge_i == 0:
                if abs_eta < 2.0:
                    pt_cut = 1.0
                else:
                    pt_cut = 2.0
                    
                if np.round((pt_i * weight_i) / 0.25) * 0.25 >= pt_cut:
                    eff_pt = pt_i * weight_i
                    eff_pt = np.round(eff_pt / 0.25) * 0.25
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)

            if charge_i !=0:
                if nnVtxScore_i > 0.1:
                    eff_pt = pt_i
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)
        ###############
        # HGCAL no-TK
        ###############
        elif 2.5 < abs_eta < 3.0:
            continue  # your original code skipped them

        ###############
        # HF
        ###############
        elif 3.0 < abs_eta < 5.2:
            continue  # skipped in your code
    # store per-event results to compute the MET later
    selected_counts.append(len(sel_effpt))     # same as before, but using final selected
    selected_pts.append(sel_pt)
    selected_etas.append(sel_eta)
    selected_phis.append(sel_phi)
    selected_masses.append(sel_mass)
    selected_effective_pts.append(sel_effpt)

# %%
# Plot.original PUPPI collection
plt.figure(figsize=(7,7))

bins = np.linspace(0, 150, 30)  # 10 bins from 0 to 30
plt.hist(selected_counts, bins=bins, alpha=0.7, color='darkorange', label='original PUPPI')
plt.xlabel('Multiplicity')
plt.ylabel('Events')
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Make the new PUPPI collection using new target as PUPPI weight

# %%
# -----------------------------------
# Helper: safe conversion to awkward
# -----------------------------------
def to_ak(x):
    # Avoid passing numpy object arrays directly into awkward
    if isinstance(x, np.ndarray) and x.dtype == object:
        x = x.tolist()
    return ak.Array(x)

# ------------------------------------------------------
# Extract branches
# ------------------------------------------------------

# Focusing on charged in the cones only
# ------------------------------------------------------
#genPtSum  = arrays["L1PuppiCands_genChPlusMatchedNe0p2"]
#recoPtSum = arrays["L1PuppiCands_recoDen_seedPlusCh0p2"]

# Looking at all particles
# ------------------------------------------------------
genPtSum  = arrays["L1PuppiCands_genPtSum0p2"]
recoPtSum = arrays["L1PuppiCands_recoDen_seedPlusAll0p2"]

# Ensure these are awkward (uproot often already returns awkward, but this is safe)
ak_genPtSum  = to_ak(genPtSum)
ak_recoPtSum = to_ak(recoPtSum)

# ------------------------------------------
# Compute *new* PUPPI weight (awkward-safe)
# ------------------------------------------
# Add epsilon as same structure, avoid python float broadcasting surprises
eps = 1e-6
#ak_new_weight = ak_genPtSum / (ak_recoPtSum + eps)
ak_new_weight = ak_genPtSum / (ak_recoPtSum)


# Convert pt/charge/weight safely
akpt          = to_ak(pt)
akcharge      = to_ak(charge)
ak_old_weight = to_ak(weight)

# -------------------------
# MASK FOR NEUTRAL CANDIDATES ONLY
# -------------------------
neutral_mask = (akcharge == 0)

pt_neutral         = akpt[neutral_mask]
old_weight_neutral = ak_old_weight[neutral_mask]
new_weight_neutral = ak_new_weight[neutral_mask]

# Corrected pTs
pt_corr_old = pt_neutral * old_weight_neutral
pt_corr_new = pt_neutral * new_weight_neutral

# -----------------------------------------------------------------
# Flatten safely -> numpy
# -----------------------------------------------------------------
def flat_finite(x):
    x = ak.drop_none(x)
    x = ak.to_numpy(ak.flatten(x, axis=None))
    return x[np.isfinite(x)]

flat_pt     = flat_finite(pt_neutral)
flat_pt_old = flat_finite(pt_corr_old)
flat_pt_new = flat_finite(pt_corr_new)

# -------------------------
# Plot (density=True)
# -------------------------
plt.figure(figsize=(10, 6))
bins = np.linspace(0, 30, 60)

plt.hist(flat_pt, bins=bins, histtype="step", linewidth=2, density=True,
         label="Original pT")
plt.hist(flat_pt_old, bins=bins, histtype="step", linewidth=2, density=True,
         label="Corrected pT (current PUPPI weight)")
plt.hist(flat_pt_new, bins=bins, histtype="step", linewidth=2, density=True,
         label="Corrected pT (New PUPPI weight)")

plt.xlabel("Neutral candidate pT [GeV]")
plt.ylabel("Normalized candidates")
plt.legend()
plt.title("Neutral candidates pT distribution")
plt.grid(False)
plt.tight_layout()
plt.show()

# -------------------------
# Plot (density=False)
# -------------------------
plt.figure(figsize=(10, 6))
bins = np.linspace(0, 30, 60)

plt.hist(flat_pt, bins=bins, histtype="step", linewidth=2, density=False,
         label="Original pT")
plt.hist(flat_pt_old, bins=bins, histtype="step", linewidth=2, density=False,
         label="Corrected pT (current PUPPI weight)")
plt.hist(flat_pt_new, bins=bins, histtype="step", linewidth=2, density=False,
         label="Corrected pT (New PUPPI weight)")

plt.xlabel("Neutral candidate pT [GeV]")
plt.ylabel("Candidates")
plt.legend()
plt.title("Neutral candidates pT distribution")
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 63
#      60     x = ak.to_numpy(ak.flatten(x, axis=None))
#      61     return x[np.isfinite(x)]
# ---> 63 flat_pt     = flat_finite(pt_neutral)
#      64 flat_pt_old = flat_finite(pt_corr_old)
#      65 flat_pt_new = flat_finite(pt_corr_new)
#
# Cell In[18], line 59, in flat_finite(x)
#      58 def flat_finite(x):
# ---> 59     x = ak.drop_none(x)
#      60     x = ak.to_numpy(ak.flatten(x, axis=None))
#      61     return x[np.isfinite(x)]
#
# AttributeError: module 'awkward' has no attribute 'drop_none'

# %%
def flat_finite(x):
    x = ak.drop_none(x)
    x = ak.to_numpy(ak.flatten(x, axis=None))
    return x[np.isfinite(x)]

ak_old_w  = to_ak(weight)
ak_new_w  = to_ak(ak_new_weight)
ak_charge = to_ak(charge)

neutral_mask = (ak_charge == 0)

old_w_neu = ak_old_w[neutral_mask]
new_w_neu = ak_new_w[neutral_mask]

flat_old_w = flat_finite(old_w_neu)
flat_new_w = flat_finite(new_w_neu)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 15
#      12 old_w_neu = ak_old_w[neutral_mask]
#      13 new_w_neu = ak_new_w[neutral_mask]
# ---> 15 flat_old_w = flat_finite(old_w_neu)
#      16 flat_new_w = flat_finite(new_w_neu)
#
# Cell In[19], line 2, in flat_finite(x)
#       1 def flat_finite(x):
# ----> 2     x = ak.drop_none(x)
#       3     x = ak.to_numpy(ak.flatten(x, axis=None))
#       4     return x[np.isfinite(x)]
#
# AttributeError: module 'awkward' has no attribute 'drop_none'

# %%
# -------------------------
# Plot (log y)
# -------------------------
plt.figure(figsize=(8, 5))
#bins = np.linspace(0, 1.5, 25)
bins = np.linspace(0, 2.0, 50)

plt.hist(flat_old_w, bins=bins, histtype="step", linewidth=2, density=True,
         color="orange", label="Current PUPPI weight")
plt.hist(flat_new_w, bins=bins, histtype="step", linewidth=2, density=True,
         color="magenta", label="New PUPPI weight")

plt.xlabel("PUPPI weight")
plt.ylabel("Density")
plt.yscale("log")
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()

# -------------------------
# Plot (linear y)
# -------------------------
plt.figure(figsize=(8, 5))
#bins = np.linspace(0, 1.5, 25)
bins = np.linspace(0, 2.0, 50)

plt.hist(flat_old_w, bins=bins, histtype="step", linewidth=2, density=True,
         color="orange", label="Current PUPPI weight")
plt.hist(flat_new_w, bins=bins, histtype="step", linewidth=2, density=True,
         color="magenta", label="New PUPPI weight")

plt.xlabel("PUPPI weight")
plt.ylabel("Density")
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       5 #bins = np.linspace(0, 1.5, 25)
#       6 bins = np.linspace(0, 2.0, 50)
# ----> 8 plt.hist(flat_old_w, bins=bins, histtype="step", linewidth=2, density=True,
#       9          color="orange", label="Current PUPPI weight")
#      10 plt.hist(flat_new_w, bins=bins, histtype="step", linewidth=2, density=True,
#      11          color="magenta", label="New PUPPI weight")
#      13 plt.xlabel("PUPPI weight")
#
# NameError: name 'flat_old_w' is not defined

# %%
# -----------------------------------
# NEW PUPPI selection storage
# -----------------------------------
new_selected_counts = []
new_selected_pts = []
new_selected_etas = []
new_selected_phis = []
new_selected_masses = []
new_selected_effective_pts = []

for iev in range(len(pt)):

    sel_pt = []
    sel_eta = []
    sel_phi = []
    sel_mass = []
    sel_effpt = []

    for pt_i, weight_i, charge_i, nnVtxScore_i, eta_i, phi_i, mass_i, pdgid_i in zip(
            pt[iev], ak_new_weight[iev], charge[iev], nnVtxScore[iev],
            eta[iev], phi[iev], mass[iev], pdgid[iev]):

        abs_eta = abs(eta_i)

        ########################################
        # Barrel
        ########################################
        if abs_eta < 1.5:

            if charge_i == 0:
                if np.round((pt_i * weight_i) / 0.25) * 0.25 >= 1.0:
                    eff_pt = pt_i * weight_i
                    eff_pt = np.round(eff_pt / 0.25) * 0.25
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)

            else:
                if nnVtxScore_i > 0.1:
                    eff_pt = pt_i
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)

        ########################################
        # HGCAL with TK
        ########################################
        elif 1.5 < abs_eta < 2.5:

            if charge_i == 0:
                if abs_eta < 2.0:
                    pt_cut = 1.0
                else:
                    pt_cut = 2.0
                if np.round((pt_i * weight_i) / 0.25) * 0.25 >= pt_cut:
                    eff_pt = pt_i * weight_i
                    eff_pt = np.round(eff_pt / 0.25) * 0.25
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)

            else:
                if nnVtxScore_i > 0.1:
                    eff_pt = pt_i
                    sel_pt.append(pt_i)
                    sel_eta.append(eta_i)
                    sel_phi.append(phi_i)
                    sel_mass.append(mass_i)
                    sel_effpt.append(eff_pt)

        ########################################
        # HGCAL no-TK
        ########################################
        elif 2.5 < abs_eta < 3.0:
            continue

        ########################################
        # HF
        ########################################
        elif 3.0 < abs_eta < 5.2:
            continue

    # store per-event results for NEW PUPPI
    new_selected_counts.append(len(sel_effpt))
    new_selected_pts.append(sel_pt)
    new_selected_etas.append(sel_eta)
    new_selected_phis.append(sel_phi)
    new_selected_masses.append(sel_mass)
    new_selected_effective_pts.append(sel_effpt)

# %%
# -----------------------------------
# Plot. new PUPPI collection
# -----------------------------------
plt.figure(figsize=(7,7))

bins = np.linspace(0, 150, 30)  # 10 bins from 0 to 30
plt.hist(new_selected_counts, bins=bins, alpha=0.7, color='magenta', label='new PUPPI')
plt.xlabel('Multiplicity')
plt.ylabel('Events')
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison between the two PUPPI collections

# %%
plt.figure(figsize=(10,6))

bins = np.linspace(0, 150, 50)  
plt.hist(selected_counts, bins=bins, alpha=0.7, color='darkorange', label='original PUPPI')

plt.hist(new_selected_counts, bins=bins, alpha=0.7, color='magenta', label='new PUPPI')
plt.xlabel('Multiplicity')
plt.ylabel('Events')
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Compute MET for the two PUPPI collections

# %%
# -----------------------------------
# MET for current PUPPI
# -----------------------------------
met_x = [-np.sum(pt * np.cos(phi)) for pt, phi in zip(selected_pts, selected_phis)]
met_y = [-np.sum(pt * np.sin(phi)) for pt, phi in zip(selected_pts, selected_phis)]
met = [np.sqrt(mx**2 + my**2) for mx, my in zip(met_x, met_y)]

# -----------------------------------
# MET for new PUPPI
# -----------------------------------
new_met_x = [-np.sum(pt * np.cos(phi)) for pt, phi in zip(new_selected_pts, new_selected_phis)]
new_met_y = [-np.sum(pt * np.sin(phi)) for pt, phi in zip(new_selected_pts, new_selected_phis)]
new_met = [np.sqrt(mx**2 + my**2) for mx, my in zip(new_met_x, new_met_y)]

# -----------------------------------
# GEN MET
# -----------------------------------
genMet = arrays["genMetCentral_pt"]

# %%
# ---------- Plot ----------
plt.figure(figsize=(10,6))

bins = np.linspace(0, 210, 50)  
hist_old, _ = np.histogram(met, bins=bins)
hist_new, _ = np.histogram(new_met, bins=bins)
hist_gen, _ = np.histogram(genMet, bins=bins)


plt.hist(new_met, bins=bins, histtype='step', label='Current PUPPI', color='orange',
         linewidth=2)
plt.hist(met, bins=bins, histtype='step', label='New PUPPI', color='magenta',
         linewidth=2)
plt.hist(genMet, bins=bins, histtype='step', label='GEN MET',  color='green',
         linewidth=2)

# ---------- Labels ----------
plt.xlabel(r"$p_{\mathrm{T}}^{\text{miss}}$ [GeV]")
plt.ylabel("Events")

plt.legend(frameon=False)
plt.tight_layout()
plt.show()

int_old = np.sum(hist_old)
int_new = np.sum(hist_new)

print(f"Integral recomputed MET: {int_old}")
print(f"Integral stored MET: {int_new}")
# Out:
# Integral recomputed MET: 9821
# Integral stored MET: 9823

# %%
# Assume met_stored = stored puppiMET_pt, met_computed = your recomputed MET
met = np.array(met)
new_met = np.array(new_met)

bins = np.linspace(0, 200, 20)
bin_centers = []

response_stored = []
response_computed = []
response_err_stored = []
response_err_computed = []

resolution_stored = []
resolution_computed = []
resolution_err_stored = []
resolution_err_computed = []

for i in range(len(bins)-1):
    mask = (genMet >= bins[i]) & (genMet < bins[i+1])
    if np.sum(mask) == 0:
        continue
    bin_centers.append(0.5*(bins[i]+bins[i+1]))

    # Response
    resp_s = np.mean(met[mask])/np.mean(genMet[mask])
    resp_c = np.mean(new_met[mask])/np.mean(genMet[mask])
    response_stored.append(resp_s)
    response_computed.append(resp_c)
    response_err_stored.append(np.std(met[mask]/genMet[mask])/np.sqrt(np.sum(mask)))
    response_err_computed.append(np.std(new_met[mask]/genMet[mask])/np.sqrt(np.sum(mask)))

    # Resolution
    diff_s = met[mask]-genMet[mask]
    diff_c = new_met[mask]-genMet[mask]
    res_s = np.sqrt(np.mean(diff_s**2))
    res_c = np.sqrt(np.mean(diff_c**2))
    resolution_stored.append(res_s)
    resolution_computed.append(res_c)
    resolution_err_stored.append(np.std(diff_s)/np.sqrt(np.sum(mask)))
    resolution_err_computed.append(np.std(diff_c)/np.sqrt(np.sum(mask)))

# ------------------------
# Response comparison
plt.figure(figsize=(8,6))
plt.errorbar(bin_centers, response_stored, yerr=response_err_stored, fmt='o', label='Current PUPPI', color='orange')
plt.errorbar(bin_centers, response_computed, yerr=response_err_computed, fmt='o', label='New PUPPI', color='magenta')
plt.axhline(1.0, color='k', linestyle='--', label='Ideal response')
plt.xlabel("gen MET [GeV]", fontsize=18)
plt.ylabel("MET response <MET_reco>/<MET_gen>", fontsize=18)
plt.ylim(0, 4)
plt.legend()
plt.grid(False)
plt.tight_layout()

# Add CMS style label
hep.cms.label(
    "Preliminary",
    data=False,
    com=14,
    loc=0  # Top-left corner
)

plt.show()

# ------------------------
# Resolution comparison
plt.figure(figsize=(8,6))
plt.errorbar(bin_centers, resolution_stored, yerr=resolution_err_stored, fmt='o', label='Current PUPPI', color='orange')
plt.errorbar(bin_centers, resolution_computed, yerr=resolution_err_computed, fmt='o', label='New PUPPI', color='magenta')
plt.xlabel("gen MET [GeV]", fontsize=18)
plt.ylabel("MET resolution [GeV]", fontsize=18)
plt.ylim(0, max(max(resolution_stored), max(resolution_computed))*1.3)
plt.legend()
plt.grid(False)
plt.tight_layout()
# Add CMS style label
hep.cms.label(
    "Preliminary",
    data=False,
    com=14,
    loc=0  # Top-left corner
)

plt.show()
